# %% [markdown]
# ## EDA AND PREPROCESSING FRENCH TEXT

# %%
content = "D'où viennent ces influences mystérieuses qui changent en découragement notre bonheur et notre confiance en détresse. On dirait que l'air, l'air invisible est plein d'inconnaissables Puissances, dont nous subissons les voisinages mystérieux. Je m'éveille plein de gaîté, avec des envies de chanter dans la gorge.--Pourquoi?--Je descends le long de l'eau; et soudain, après une courte promenade, je rentre désolé, comme si quelque malheur m'attendait chez moi.--Pourquoi?--Est-ce un frisson de froid qui, frôlant ma peau, a ébranlé mes nerfs et assombri mon âme? Est-ce la forme des nuages, ou la couleur du jour, la couleur des choses, si variable, qui, passant par mes yeux, a troublé ma pensée? Sait-on? Tout ce qui nous entoure, tout ce que nous voyons sans le regarder, tout ce que nous frôlons sans le connaître, tout ce que nous touchons sans le palper, tout ce que nous rencontrons sans le distinguer, a sur nous, sur nos organes et, par eux, sur nos idées, sur notre coeur lui-même, des effets rapides, surprenants et inexplicables?"

# %%
content = content.lower()

# %%
import nltk
from nltk.tokenize import word_tokenize
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
tokens = word_tokenize(content,language='french')
print(tokens)
# Out:
# ["d'où", 'viennent', 'ces', 'influences', 'mystérieuses', 'qui', 'changent', 'en', 'découragement', 'notre', 'bonheur', 'et', 'notre', 'confiance', 'en', 'détresse', '.', 'on', 'dirait', 'que', "l'air", ',', "l'air", 'invisible', 'est', 'plein', "d'inconnaissables", 'puissances', ',', 'dont', 'nous', 'subissons', 'les', 'voisinages', 'mystérieux', '.', 'je', "m'éveille", 'plein', 'de', 'gaîté', ',', 'avec', 'des', 'envies', 'de', 'chanter', 'dans', 'la', 'gorge.', '--', 'pourquoi', '?', '--', 'je', 'descends', 'le', 'long', 'de', "l'eau", ';', 'et', 'soudain', ',', 'après', 'une', 'courte', 'promenade', ',', 'je', 'rentre', 'désolé', ',', 'comme', 'si', 'quelque', 'malheur', "m'attendait", 'chez', 'moi.', '--', 'pourquoi', '?', '--', 'est-ce', 'un', 'frisson', 'de', 'froid', 'qui', ',', 'frôlant', 'ma', 'peau', ',', 'a', 'ébranlé', 'mes', 'nerfs', 'et', 'assombri', 'mon', 'âme', '?', 'est-ce', 'la', 'forme', 'des', 'nuages', ',', 'ou', 'la', 'couleur', 'du', 'jour', ',', 'la', 'couleur', 'des', 'choses', ',', 'si', 'variable', ',', 'qui', ',', 'passant', 'par', 'mes', 'yeux', ',', 'a', 'troublé', 'ma', 'pensée', '?', 'sait-on', '?', 'tout', 'ce', 'qui', 'nous', 'entoure', ',', 'tout', 'ce', 'que', 'nous', 'voyons', 'sans', 'le', 'regarder', ',', 'tout', 'ce', 'que', 'nous', 'frôlons', 'sans', 'le', 'connaître', ',', 'tout', 'ce', 'que', 'nous', 'touchons', 'sans', 'le', 'palper', ',', 'tout', 'ce', 'que', 'nous', 'rencontrons', 'sans', 'le', 'distinguer', ',', 'a', 'sur', 'nous', ',', 'sur', 'nos', 'organes', 'et', ',', 'par', 'eux', ',', 'sur', 'nos', 'idées', ',', 'sur', 'notre', 'coeur', 'lui-même', ',', 'des', 'effets', 'rapides', ',', 'surprenants', 'et', 'inexplicables', '?']

# %%
#https://stackoverflow.com/questions/42428390/nltk-french-tokenizer-in-python-not-working

#Tokenize with RegExp

#Test online : https://regex101.com/
#https://docs.microsoft.com/fr-fr/dotnet/standard/base-types/regular-expression-language-quick-reference

from nltk import RegexpTokenizer
toknizer = RegexpTokenizer(r"\w'|\w+|[^\w\s]")
tokens = toknizer.tokenize(content)
tokens
# Out:
# ["d'",
#  'où',
#  'viennent',
#  'ces',
#  'influences',
#  'mystérieuses',
#  'qui',
#  'changent',
#  'en',
#  'découragement',
#  'notre',
#  'bonheur',
#  'et',
#  'notre',
#  'confiance',
#  'en',
#  'détresse',
#  '.',
#  'on',
#  'dirait',
#  'que',
#  "l'",
#  'air',
#  ',',
#  "l'",
#  'air',
#  'invisible',
#  'est',
#  'plein',
#  "d'",
#  'inconnaissables',
#  'puissances',
#  ',',
#  'dont',
#  'nous',
#  'subissons',
#  'les',
#  'voisinages',
#  'mystérieux',
#  '.',
#  'je',
#  "m'",
#  'éveille',
#  'plein',
#  'de',
#  'gaîté',
#  ',',
#  'avec',
#  'des',
#  'envies',
#  'de',
#  'chanter',
#  'dans',
#  'la',
#  'gorge',
#  '.',
#  '-',
#  '-',
#  'pourquoi',
#  '?',
#  '-',
#  '-',
#  'je',
#  'descends',
#  'le',
#  'long',
#  'de',
#  "l'",
#  'eau',
#  ';',
#  'et',
#  'soudain',
#  ',',
#  'après',
#  'une',
#  'courte',
#  'promenade',
#  ',',
#  'je',
#  'rentre',
#  'désolé',
#  ',',
#  'comme',
#  'si',
#  'quelque',
#  'malheur',
#  "m'",
#  'attendait',
#  'chez',
#  'moi',
#  '.',
#  '-',
#  '-',
#  'pourquoi',
#  '?',
#  '-',
#  '-',
#  'est',
#  '-',
#  'ce',
#  'un',
#  'frisson',
#  'de',
#  'froid',
#  'qui',
#  ',',
#  'frôlant',
#  'ma',
#  'peau',
#  ',',
#  'a',
#  'ébranlé',
#  'mes',
#  'nerfs',
#  'et',
#  'assombri',
#  'mon',
#  'âme',
#  '?',
#  'est',
#  '-',
#  'ce',
#  'la',
#  'forme',
#  'des',
#  'nuages',
#  ',',
#  'ou',
#  'la',
#  'couleur',
#  'du',
#  'jour',
#  ',',
#  'la',
#  'couleur',
#  'des',
#  'choses',
#  ',',
#  'si',
#  'variable',
#  ',',
#  'qui',
#  ',',
#  'passant',
#  'par',
#  'mes',
#  'yeux',
#  ',',
#  'a',
#  'troublé',
#  'ma',
#  'pensée',
#  '?',
#  'sait',
#  '-',
#  'on',
#  '?',
#  'tout',
#  'ce',
#  'qui',
#  'nous',
#  'entoure',
#  ',',
#  'tout',
#  'ce',
#  'que',
#  'nous',
#  'voyons',
#  'sans',
#  'le',
#  'regarder',
#  ',',
#  'tout',
#  'ce',
#  'que',
#  'nous',
#  'frôlons',
#  'sans',
#  'le',
#  'connaître',
#  ',',
#  'tout',
#  'ce',
#  'que',
#  'nous',
#  'touchons',
#  'sans',
#  'le',
#  'palper',
#  ',',
#  'tout',
#  'ce',
#  'que',
#  'nous',
#  'rencontrons',
#  'sans',
#  'le',
#  'distinguer',
#  ',',
#  'a',
#  'sur',
#  'nous',
#  ',',
#  'sur',
#  'nos',
#  'organes',
#  'et',
#  ',',
#  'par',
#  'eux',
#  ',',
#  'sur',
#  'nos',
#  'idées',
#  ',',
#  'sur',
#  'notre',
#  'coeur',
#  'lui',
#  '-',
#  'même',
#  ',',
#  'des',
#  'effets',
#  'rapides',
#  ',',
#  'surprenants',
#  'et',
#  'inexplicables',
#  '?']

# %%
newTokens = []
for word in tokens :
  if (len(word)>2):
    newTokens.append(word)

print(newTokens)
# Out:
# ['viennent', 'ces', 'influences', 'mystérieuses', 'qui', 'changent', 'découragement', 'notre', 'bonheur', 'notre', 'confiance', 'détresse', 'dirait', 'que', 'air', 'air', 'invisible', 'est', 'plein', 'inconnaissables', 'puissances', 'dont', 'nous', 'subissons', 'les', 'voisinages', 'mystérieux', 'éveille', 'plein', 'gaîté', 'avec', 'des', 'envies', 'chanter', 'dans', 'gorge', 'pourquoi', 'descends', 'long', 'eau', 'soudain', 'après', 'une', 'courte', 'promenade', 'rentre', 'désolé', 'comme', 'quelque', 'malheur', 'attendait', 'chez', 'moi', 'pourquoi', 'est', 'frisson', 'froid', 'qui', 'frôlant', 'peau', 'ébranlé', 'mes', 'nerfs', 'assombri', 'mon', 'âme', 'est', 'forme', 'des', 'nuages', 'couleur', 'jour', 'couleur', 'des', 'choses', 'variable', 'qui', 'passant', 'par', 'mes', 'yeux', 'troublé', 'pensée', 'sait', 'tout', 'qui', 'nous', 'entoure', 'tout', 'que', 'nous', 'voyons', 'sans', 'regarder', 'tout', 'que', 'nous', 'frôlons', 'sans', 'connaître', 'tout', 'que', 'nous', 'touchons', 'sans', 'palper', 'tout', 'que', 'nous', 'rencontrons', 'sans', 'distinguer', 'sur', 'nous', 'sur', 'nos', 'organes', 'par', 'eux', 'sur', 'nos', 'idées', 'sur', 'notre', 'coeur', 'lui', 'même', 'des', 'effets', 'rapides', 'surprenants', 'inexplicables']

# %%
from nltk.corpus import stopwords
nltk.download('stopwords')
stopWords = set(stopwords.words('french'))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
print(stopWords)
# Out:
# {'été', 'ayantes', 'eusse', 'il', 'on', 'soient', 'étais', 'étant', 'eus', 'mes', 'notre', 'en', 'et', 'même', 'sommes', 'aurais', 'eûtes', 'aurions', 'ils', 'le', 'du', 'furent', 'elle', 'êtes', 'eussiez', 'suis', 'vos', 'eûmes', 'étantes', 'son', 'votre', 'avez', 'serez', 'étaient', 'ayants', 'aviez', 'vous', 'fussions', 'étions', 'sa', 'pour', 'auriez', 'tes', 'fus', 'fut', 'ce', 'sur', 'serons', 'aurez', 'aux', 'dans', 'es', 'm', 'auront', 'ai', 'des', 'qu', 'seras', 'j', 'seront', 'soit', 'un', 'fûmes', 'aura', 'auras', 'aies', 'eussent', 'je', 'une', 'ma', 'de', 'toi', 'eusses', 'ayant', 'étante', 'eu', 'serait', 'leur', 'étés', 'fusses', 'soyez', 'c', 'ton', 'y', 'ayons', 'fussiez', 'eurent', 's', 'au', 'eux', 'ta', 'seriez', 'fusse', 'serions', 'l', 'avait', 'aurons', 'aurait', 'as', 'à', 'est', 'serai', 'ne', 'serais', 'les', 'était', 'sera', 'ont', 'mais', 'soyons', 'eue', 'avons', 'ou', 'eussions', 'que', 'fussent', 'eut', 'eût', 'ayante', 'ses', 'eues', 't', 'avaient', 'fût', 'qui', 'me', 'auraient', 'ait', 'nous', 'étée', 'avions', 'aurai', 'tu', 'étiez', 'mon', 'seraient', 'nos', 'ayez', 'par', 'avec', 'ces', 'sois', 'moi', 'se', 'aient', 'd', 'sont', 'étants', 'lui', 'fûtes', 'aie', 'te', 'étées', 'pas', 'avais', 'la', 'n'}

# %%
maListe = ['si','plus','grand']

# %%
clean_1 = [word for word in newTokens if word not in maListe]

# %%
cleanTokens = [word for word in clean_1 if word not in stopWords]
cleanTokens
# Out:
# ['viennent',
#  'influences',
#  'mystérieuses',
#  'changent',
#  'découragement',
#  'bonheur',
#  'confiance',
#  'détresse',
#  'dirait',
#  'air',
#  'air',
#  'invisible',
#  'plein',
#  'inconnaissables',
#  'puissances',
#  'dont',
#  'subissons',
#  'voisinages',
#  'mystérieux',
#  'éveille',
#  'plein',
#  'gaîté',
#  'envies',
#  'chanter',
#  'gorge',
#  'pourquoi',
#  'descends',
#  'long',
#  'eau',
#  'soudain',
#  'après',
#  'courte',
#  'promenade',
#  'rentre',
#  'désolé',
#  'comme',
#  'quelque',
#  'malheur',
#  'attendait',
#  'chez',
#  'pourquoi',
#  'frisson',
#  'froid',
#  'frôlant',
#  'peau',
#  'ébranlé',
#  'nerfs',
#  'assombri',
#  'âme',
#  'forme',
#  'nuages',
#  'couleur',
#  'jour',
#  'couleur',
#  'choses',
#  'variable',
#  'passant',
#  'yeux',
#  'troublé',
#  'pensée',
#  'sait',
#  'tout',
#  'entoure',
#  'tout',
#  'voyons',
#  'sans',
#  'regarder',
#  'tout',
#  'frôlons',
#  'sans',
#  'connaître',
#  'tout',
#  'touchons',
#  'sans',
#  'palper',
#  'tout',
#  'rencontrons',
#  'sans',
#  'distinguer',
#  'organes',
#  'idées',
#  'coeur',
#  'effets',
#  'rapides',
#  'surprenants',
#  'inexplicables']

# %%
from nltk.stem import SnowballStemmer
fr = SnowballStemmer('french')

# %%
[fr.stem(word) for word in cleanTokens]
# Out:
# ['viennent',
#  'influenc',
#  'mystéri',
#  'changent',
#  'décourag',
#  'bonheur',
#  'confianc',
#  'détress',
#  'dir',
#  'air',
#  'air',
#  'invisibl',
#  'plein',
#  'inconnaiss',
#  'puissanc',
#  'dont',
#  'sub',
#  'voisinag',
#  'mystéri',
#  'éveil',
#  'plein',
#  'gaît',
#  'envi',
#  'chant',
#  'gorg',
#  'pourquoi',
#  'descend',
#  'long',
#  'eau',
#  'soudain',
#  'apres',
#  'court',
#  'promenad',
#  'rentr',
#  'désol',
#  'comm',
#  'quelqu',
#  'malheur',
#  'attend',
#  'chez',
#  'pourquoi',
#  'frisson',
#  'froid',
#  'frôl',
#  'peau',
#  'ébranl',
#  'nerf',
#  'assombr',
#  'âme',
#  'form',
#  'nuag',
#  'couleur',
#  'jour',
#  'couleur',
#  'chos',
#  'variabl',
#  'pass',
#  'yeux',
#  'troubl',
#  'pens',
#  'sait',
#  'tout',
#  'entour',
#  'tout',
#  'voyon',
#  'san',
#  'regard',
#  'tout',
#  'frôlon',
#  'san',
#  'connaîtr',
#  'tout',
#  'touchon',
#  'san',
#  'palp',
#  'tout',
#  'rencontron',
#  'san',
#  'distingu',
#  'organ',
#  'idé',
#  'coeur',
#  'effet',
#  'rapid',
#  'surpren',
#  'inexplic']
