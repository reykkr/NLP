# %% [markdown]
# # **Mohamad Ali Ghaddar**
# Assignement CSCI 372

# %%
import nltk

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# **Word Tokenization**

# %%
from nltk.tokenize import word_tokenize

# %%
sentence = "Hello everyone! My name is Mohamad Ali Ghaddar. I'm 20 years old. I study CSCI in LIU. This is my third & final year."

# %%
word_tokens=word_tokenize(sentence)

print(word_tokens)
# Out:
# ['Hello', 'everyone', '!', 'My', 'name', 'is', 'Mohamad', 'Ali', 'Ghaddar', '.', 'I', "'m", '20', 'years', 'old', '.', 'I', 'study', 'CSCI', 'in', 'LIU', '.', 'This', 'is', 'my', 'third', '&', 'final', 'year', '.']

# %% [markdown]
# **Sentence Tokenization**

# %%
from nltk import sent_tokenize

# %%
text= "Hello everyone! My name is Mohamad Ali Ghaddar. I'm 20 years old. I study CSCI in LIU. This is my third & final year."

# %%
sentence_tokens=sent_tokenize(text)

print (sentence_tokens)
# Out:
# ['Hello everyone!', 'My name is Mohamad Ali Ghaddar.', "I'm 20 years old.", 'I study CSCI in LIU.', 'This is my third & final year.']

# %% [markdown]
# **Stemming**

# %%
from nltk.stem import PorterStemmer, LancasterStemmer

# %%
porter_stemmer=PorterStemmer()

print (porter_stemmer.stem('working'))

print (porter_stemmer.stem('works'))

print (porter_stemmer.stem('worked'))
# Out:
# work
# work
# work

# %%
porter_stemmer=PorterStemmer()

print (porter_stemmer.stem('controlling'))

print (porter_stemmer.stem('controls'))

print (porter_stemmer.stem('controlled'))
# Out:
# control
# control
# control

# %%
lancaster_stemmer=LancasterStemmer()

print (lancaster_stemmer.stem('fighting'))

print (lancaster_stemmer.stem('fights'))

print (lancaster_stemmer.stem('fought'))
# Out:
# fight
# fight
# fought

# %% [markdown]
# **Lemmatization**

# %%
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# True

# %%
lemmatizer =WordNetLemmatizer()

print (lemmatizer.lemmatize("waiting"))
print (lemmatizer.lemmatize("waits"))
# Out:
# waiting
# wait

# %%
lemmatizer =WordNetLemmatizer()

print (lemmatizer.lemmatize("writing"))
print (lemmatizer.lemmatize("writes"))
# Out:
# writing
# writes

# %%
lemmatizer =WordNetLemmatizer()

print (lemmatizer.lemmatize("playing"))
print (lemmatizer.lemmatize("plays"))
# Out:
# playing
# play

# %%
def lemmatize (word):

   lemmatizer = WordNetLemmatizer()
   print ("Verb form: " + lemmatizer.lemmatize(word, pos="v"))
   print ("Noun form: " + lemmatizer.lemmatize(word, pos="n"))
   print ("Adverb form: " + lemmatizer.lemmatize(word, pos="r"))
   print ("Adjective form: " + lemmatizer.lemmatize(word, pos="a"))

# %%
lemmatize ("waiting")

lemmatize ("writing")

lemmatize ("playing")
# Out:
# Verb form: wait
# Noun form: waiting
# Adverb form: waiting
# Adjective form: waiting
# Verb form: write
# Noun form: writing
# Adverb form: writing
# Adjective form: writing
# Verb form: play
# Noun form: playing
# Adverb form: playing
# Adjective form: playing

# %% [markdown]
# **POS Tagging**

# %%
from nltk import word_tokenize, pos_tag
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
sentence ="The weather is nice today."

sentence_tokens=word_tokenize(sentence)

print (sentence_tokens)
# Out:
# ['The', 'weather', 'is', 'nice', 'today', '.']

# %%
pos_tag(sentence_tokens)
# Out:
# [('The', 'DT'),
#  ('weather', 'NN'),
#  ('is', 'VBZ'),
#  ('nice', 'JJ'),
#  ('today', 'NN'),
#  ('.', '.')]

# %% [markdown]
# **Chunking**

# %%
text="I live in ghazieh, south of Lebanon"

tokens= nltk.word_tokenize(text)

print (tokens)

tag=nltk.pos_tag(tokens)
# Out:
# ['I', 'live', 'in', 'ghazieh', ',', 'south', 'of', 'Lebanon']

# %%
print(tag)
# Out:
# [('I', 'PRP'), ('live', 'VBP'), ('in', 'IN'), ('ghazieh', 'NN'), (',', ','), ('south', 'NN'), ('of', 'IN'), ('Lebanon', 'NNP')]

# %%
grammar="NP: {<DT>?<JJ>*<NN>}"

cp=nltk.RegexpParser(grammar)

# %%
result=cp.parse(tag)

print (result)
# Out:
# (S
#   I/PRP
#   live/VBP
#   in/IN
#   (NP ghazieh/NN)
#   ,/,
#   (NP south/NN)
#   of/IN
#   Lebanon/NNP)
